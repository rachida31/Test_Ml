# %% [markdown]
# # Spacy

# %% [markdown]
# ### Créatio d'un objet nlp en langue française

# %%
#Importer la classe de langue "French"
from spacy.lang.fr import French

#Création de l'objet nlp
nlp = French()

# %% [markdown]
# ### Création de l'objet “Doc”

# %%
# Création d'un objet doc en traitant une chaine de caractères avec l'objet nlp
doc = nlp("MARINE LE PEN SOUHAITE UN “MORATOIRE SUR L’AUGMENTATION DE LA CONTRIBUTION FRANÇAISE À L’UNION EUROPÉENNE”RMC, Bourdin Direct, le 13 octobre 2020, 11’20’’IMPOSSIBLE   NewsletterUne fois voté au sein de l’Union, le budget européen doit être respecté par tous les États membres. Marine Le Pen, si elle est élue à la présidence de la République, ne pourra suspendre le versement français qu’en renégociant ce budget avec les 26 autres Etats, ce qui n’est pas prévu par les traités. Ou alors elle devra attendre l’échéance de 2027, date prévue pour la négociation du prochain budget.Par Ithry Marouan, étudiante en master droit européen à l'Université de Lille, sous la direction de Vincent Couronne, docteur en droit européen, chercheur au laboratoire VIP (Paris-Saclay), le 15 octobre 2020")

# Parcourir sur les tokens dans un Doc
for token in doc:
    print(token.text)
# Out:
# MARINE
# LE
# PEN
# SOUHAITE
# UN
# “
# MORATOIRE
# SUR
# L’
# AUGMENTATION
# DE
# LA
# CONTRIBUTION
# FRANÇAISE
# À
# L’
# UNION
# EUROPÉENNE”RMC
# ,
# Bourdin
# Direct
# ,
# le
# 13
# octobre
# 2020
# ,
# 11’20’’IMPOSSIBLE
#
# NewsletterUne
# fois
# voté
# au
# sein
# de
# l’
# Union
# ,
# le
# budget
# européen
# doit
# être
# respecté
# par
# tous
# les
# États
# membres
# .
# Marine
# Le
# Pen
# ,
# si
# elle
# est
# élue
# à
# la
# présidence
# de
# la
# République
# ,
# ne
# pourra
# suspendre
# le
# versement
# français
# qu’
# en
# renégociant
# ce
# budget
# avec
# les
# 26
# autres
# Etats
# ,
# ce
# qui
# n’
# est
# pas
# prévu
# par
# les
# traités
# .
# Ou
# alors
# elle
# devra
# attendre
# l’
# échéance
# de
# 2027
# ,
# date
# prévue
# pour
# la
# négociation
# du
# prochain
# budget
# .
# Par
# Ithry
# Marouan
# ,
# étudiante
# en
# master
# droit
# européen
# à
# l'
# Université
# de
# Lille
# ,
# sous
# la
# direction
# de
# Vincent
# Couronne
# ,
# docteur
# en
# droit
# européen
# ,
# chercheur
# au
# laboratoire
# VIP
# (
# Paris
# -
# Saclay
# )
# ,
# le
# 15
# octobre
# 2020

# %% [markdown]
# ### Token

# %%
# Obtenir le Token d'indice 1 au sein du Doc.
token = doc[1]

# Obtiens le texte du token avec l'attribut .text
print(token.text)
# Out:
# LE

# %% [markdown]
# ### Span

# %%
# Une portion du Doc est un objet Span
span = doc[1:3]

# Obtiens le texte du span avec l'attribut .text
print(span.text)
# Out:
# LE PEN

# %% [markdown]
# ### Attributs lexicaux

# %%
doc1 = nlp("Cela coûte 5 € dix .")
print("Index :   ", [token.i for token in doc1])
print("Text :    ", [token.text for token in doc1])

print("is_alpha :", [token.is_alpha for token in doc1])
print("is_punct :", [token.is_punct for token in doc1])
print("like_num :", [token.like_num for token in doc1])
# Out:
# Index :    [0, 1, 2, 3, 4, 5]
# Text :     ['Cela', 'coûte', '5', '€', 'dix', '.']
# is_alpha : [True, True, False, False, True, False]
# is_punct : [False, False, False, False, False, True]
# like_num : [False, False, True, False, True, False]

# %% [markdown]
# ### Télécharger le modèle pré-entraîné de la langue française.

# %%
# Importation de Spacy
import spacy
# Charger le paquet de modèle de la langue française.
nlp = spacy.load("fr_core_news_sm")

# %% [markdown]
# #### Marquage de partie de parole avec POS

# %%
# Création d'un objet doc en traitant une chaine de caractères avec l'objet nlp
doc = nlp("MARINE LE PEN SOUHAITE UN “MORATOIRE SUR L’AUGMENTATION DE LA CONTRIBUTION FRANÇAISE À L’UNION EUROPÉENNE”RMC, Bourdin Direct, le 13 octobre 2020, 11’20’’IMPOSSIBLE   NewsletterUne fois voté au sein de l’Union, le budget européen doit être respecté par tous les États membres. Marine Le Pen, si elle est élue à la présidence de la République, ne pourra suspendre le versement français qu’en renégociant ce budget avec les 26 autres Etats, ce qui n’est pas prévu par les traités. Ou alors elle devra attendre l’échéance de 2027, date prévue pour la négociation du prochain budget.Par Ithry Marouan, étudiante en master droit européen à l'Université de Lille, sous la direction de Vincent Couronne, docteur en droit européen, chercheur au laboratoire VIP (Paris-Saclay), le 15 octobre 2020")
# Itère sur les tokens
for token in doc:
    # Affichage de texte et l'étiquette de partie de discours prédite
     print(token.text, "------->", token.pos_)
# Out:
# MARINE -------> NOUN
# LE -------> DET
# PEN -------> NOUN
# SOUHAITE -------> PROPN
# UN -------> DET
# “ -------> PUNCT
# MORATOIRE -------> NOUN
# SUR -------> ADP
# L’ -------> NOUN
# AUGMENTATION -------> NOUN
# DE -------> ADP
# LA -------> DET
# CONTRIBUTION -------> NOUN
# FRANÇAISE -------> ADJ
# À -------> ADP
# L’ -------> NOUN
# UNION -------> PROPN
# EUROPÉENNE”RMC -------> PROPN
# , -------> PUNCT
# Bourdin -------> PROPN
# Direct -------> PROPN
# , -------> PUNCT
# le -------> DET
# 13 -------> NUM
# octobre -------> NOUN
# 2020 -------> NUM
# , -------> PUNCT
# 11’20’’IMPOSSIBLE -------> NUM
#    -------> SPACE
# NewsletterUne -------> CCONJ
# fois -------> NOUN
# voté -------> VERB
# au -------> DET
# sein -------> NOUN
# de -------> ADP
# l’ -------> PROPN
# Union -------> PROPN
# , -------> PUNCT
# le -------> DET
# budget -------> NOUN
# européen -------> ADJ
# doit -------> VERB
# être -------> AUX
# respecté -------> VERB
# par -------> ADP
# tous -------> ADJ
# les -------> DET
# États -------> NOUN
# membres -------> ADJ
# . -------> PUNCT
# Marine -------> NOUN
# Le -------> DET
# Pen -------> PROPN
# , -------> PUNCT
# si -------> SCONJ
# elle -------> PRON
# est -------> AUX
# élue -------> VERB
# à -------> ADP
# la -------> DET
# présidence -------> NOUN
# de -------> ADP
# la -------> DET
# République -------> NOUN
# , -------> PUNCT
# ne -------> ADV
# pourra -------> VERB
# suspendre -------> VERB
# le -------> DET
# versement -------> NOUN
# français -------> ADJ
# qu’ -------> PRON
# en -------> ADP
# renégociant -------> VERB
# ce -------> DET
# budget -------> NOUN
# avec -------> ADP
# les -------> DET
# 26 -------> NUM
# autres -------> ADJ
# Etats -------> NOUN
# , -------> PUNCT
# ce -------> PRON
# qui -------> PRON
# n’ -------> PROPN
# est -------> AUX
# pas -------> ADV
# prévu -------> VERB
# par -------> ADP
# les -------> DET
# traités -------> NOUN
# . -------> PUNCT
# Ou -------> CCONJ
# alors -------> ADV
# elle -------> PRON
# devra -------> VERB
# attendre -------> VERB
# l’ -------> NOUN
# échéance -------> NOUN
# de -------> ADP
# 2027 -------> NUM
# , -------> PUNCT
# date -------> NOUN
# prévue -------> VERB
# pour -------> ADP
# la -------> DET
# négociation -------> NOUN
# du -------> DET
# prochain -------> ADJ
# budget -------> NOUN
# . -------> PUNCT
# Par -------> ADP
# Ithry -------> PROPN
# Marouan -------> PROPN
# , -------> PUNCT
# étudiante -------> NOUN
# en -------> ADP
# master -------> VERB
# droit -------> NOUN
# européen -------> ADJ
# à -------> ADP
# l' -------> DET
# Université -------> NOUN
# de -------> ADP
# Lille -------> PROPN
# , -------> PUNCT
# sous -------> ADP
# la -------> DET
# direction -------> NOUN
# de -------> ADP
# Vincent -------> NOUN
# Couronne -------> NOUN
# , -------> PUNCT
# docteur -------> NOUN
# en -------> ADP
# droit -------> NOUN
# européen -------> ADJ
# , -------> PUNCT
# chercheur -------> NOUN
# au -------> DET
# laboratoire -------> NOUN
# VIP -------> PROPN
# ( -------> PUNCT
# Paris -------> PROPN
# - -------> PUNCT
# Saclay -------> PROPN
# ) -------> PUNCT
# , -------> PUNCT
# le -------> DET
# 15 -------> NUM
# octobre -------> NOUN
# 2020 -------> NUM

# %% [markdown]
# #### Explication d'un  parties  du discours (DET)

# %%
spacy.explain ("DET")
# Out:
# 'determiner'

# %% [markdown]
# #### Prédiction de dépendances syntaxiques avec "dep"  et a qui le mot considéré se rattacher avec "head"

# %%
for token in doc:
    print(token.text, "------>", token.dep_, "------>", token.head.text)
# Out:
# MARINE ------> ROOT ------> MARINE
# LE ------> det ------> PEN
# PEN ------> nmod ------> MARINE
# SOUHAITE ------> acl ------> PEN
# UN ------> det ------> MORATOIRE
# “ ------> punct ------> UN
# MORATOIRE ------> obj ------> SOUHAITE
# SUR ------> case ------> L’
# L’ ------> nmod ------> MORATOIRE
# AUGMENTATION ------> ROOT ------> AUGMENTATION
# DE ------> case ------> CONTRIBUTION
# LA ------> det ------> CONTRIBUTION
# CONTRIBUTION ------> nmod ------> AUGMENTATION
# FRANÇAISE ------> amod ------> CONTRIBUTION
# À ------> case ------> L’
# L’ ------> nmod ------> AUGMENTATION
# UNION ------> amod ------> L’
# EUROPÉENNE”RMC ------> amod ------> L’
# , ------> punct ------> Bourdin
# Bourdin ------> conj ------> L’
# Direct ------> amod ------> Bourdin
# , ------> punct ------> AUGMENTATION
# le ------> det ------> 13
# 13 ------> nmod ------> AUGMENTATION
# octobre ------> nmod ------> 13
# 2020 ------> nmod ------> octobre
# , ------> punct ------> 11’20’’IMPOSSIBLE
# 11’20’’IMPOSSIBLE ------> obl:mod ------> doit
#    ------>  ------> 11’20’’IMPOSSIBLE
# NewsletterUne ------> nummod ------> voté
# fois ------> fixed ------> NewsletterUne
# voté ------> nmod ------> 11’20’’IMPOSSIBLE
# au ------> case ------> sein
# sein ------> nmod ------> voté
# de ------> case ------> l’
# l’ ------> nmod ------> sein
# Union ------> flat:name ------> l’
# , ------> punct ------> doit
# le ------> det ------> budget
# budget ------> nsubj ------> doit
# européen ------> amod ------> budget
# doit ------> ROOT ------> doit
# être ------> aux:pass ------> respecté
# respecté ------> xcomp ------> doit
# par ------> case ------> États
# tous ------> amod ------> États
# les ------> det ------> États
# États ------> obl:agent ------> respecté
# membres ------> nmod ------> États
# . ------> punct ------> doit
# Marine ------> ROOT ------> Marine
# Le ------> det ------> Pen
# Pen ------> obl:mod ------> élue
# , ------> punct ------> élue
# si ------> mark ------> élue
# elle ------> nsubj ------> élue
# est ------> aux:tense ------> élue
# élue ------> ROOT ------> élue
# à ------> case ------> présidence
# la ------> det ------> présidence
# présidence ------> obl:arg ------> élue
# de ------> case ------> République
# la ------> det ------> République
# République ------> nmod ------> présidence
# , ------> punct ------> pourra
# ne ------> advmod ------> pourra
# pourra ------> advcl ------> élue
# suspendre ------> xcomp ------> pourra
# le ------> det ------> versement
# versement ------> obj ------> suspendre
# français ------> amod ------> versement
# qu’ ------> mark ------> renégociant
# en ------> iobj ------> renégociant
# renégociant ------> acl ------> versement
# ce ------> det ------> budget
# budget ------> obj ------> renégociant
# avec ------> case ------> 26
# les ------> det ------> 26
# 26 ------> nummod ------> Etats
# autres ------> amod ------> Etats
# Etats ------> obj ------> renégociant
# , ------> punct ------> pourra
# ce ------> dep ------> pourra
# qui ------> nsubj:pass ------> prévu
# n’ ------> nsubj:pass ------> prévu
# est ------> aux:pass ------> prévu
# pas ------> advmod ------> prévu
# prévu ------> acl:relcl ------> ce
# par ------> case ------> traités
# les ------> det ------> traités
# traités ------> obl:agent ------> prévu
# . ------> punct ------> élue
# Ou ------> cc ------> devra
# alors ------> advmod ------> devra
# elle ------> nsubj ------> devra
# devra ------> ROOT ------> devra
# attendre ------> xcomp ------> devra
# l’ ------> obj ------> attendre
# échéance ------> obj ------> attendre
# de ------> case ------> 2027
# 2027 ------> obl:arg ------> attendre
# , ------> punct ------> attendre
# date ------> obl:mod ------> attendre
# prévue ------> nmod ------> date
# pour ------> case ------> négociation
# la ------> det ------> négociation
# négociation ------> nmod ------> date
# du ------> case ------> budget
# prochain ------> amod ------> budget
# budget ------> nmod ------> négociation
# . ------> punct ------> devra
# Par ------> case ------> Ithry
# Ithry ------> ROOT ------> Ithry
# Marouan ------> flat:name ------> Ithry
# , ------> punct ------> Ithry
# étudiante ------> appos ------> Ithry
# en ------> mark ------> master
# master ------> acl ------> Ithry
# droit ------> advmod ------> master
# européen ------> amod ------> droit
# à ------> case ------> Université
# l' ------> det ------> Université
# Université ------> obl:arg ------> master
# de ------> case ------> Lille
# Lille ------> nmod ------> Université
# , ------> punct ------> master
# sous ------> case ------> direction
# la ------> det ------> direction
# direction ------> obl:mod ------> master
# de ------> case ------> Vincent
# Vincent ------> nmod ------> direction
# Couronne ------> amod ------> Vincent
# , ------> punct ------> direction
# docteur ------> appos ------> direction
# en ------> case ------> droit
# droit ------> nmod ------> docteur
# européen ------> amod ------> droit
# , ------> punct ------> direction
# chercheur ------> appos ------> direction
# au ------> case ------> laboratoire
# laboratoire ------> nmod ------> chercheur
# VIP ------> nmod ------> laboratoire
# ( ------> punct ------> chercheur
# Paris ------> punct ------> Ithry
# - ------> punct ------> Saclay
# Saclay ------> ROOT ------> Saclay
# ) ------> punct ------> Saclay
# , ------> punct ------> Saclay
# le ------> det ------> 15
# 15 ------> nmod ------> Saclay
# octobre ------> nmod ------> 15
# 2020 ------> nmod ------> octobre

# %% [markdown]
# ###### REMARQUE : La balise de dépendance ROOT désigne le verbe ou l'action principale de la phrase. Les autres mots sont directement ou indirectement liés au mot ROOT de la phrase.

# %% [markdown]
# #### découvrir ce que représentent les autres balises

# %%
spacy.explain("ROOT"), spacy.explain("case"), spacy.explain("acl"), spacy.explain("amod"), spacy.explain("nmod")
# Out:
# (None,
#  'case marking',
#  'clausal modifier of noun (adjectival clause)',
#  'adjectival modifier',
#  'modifier of nominal')

# %% [markdown]
# #### Visualisation des  dependence

# %%
from spacy import displacy

displacy.serve(doc, style="dep")
# Out:
# /home/rachida/anaconda3/lib/python3.8/site-packages/spacy/displacy/__init__.py:94: UserWarning: [W011] It looks like you're calling displacy.serve from within a Jupyter notebook or a similar environment. This likely means you're already running a local web server, so there's no need to make displaCy start another one. Instead, you should be able to replace displacy.serve with displacy.render to show the visualization.
#   warnings.warn(Warnings.W011)
# <span class="tex2jax_ignore"><!DOCTYPE html>
# <html lang="fr">
#     <head>
#         <title>displaCy</title>
#     </head>
#
#     <body style="font-size: 16px; font-family: -apple-system, BlinkMacSystemFont, 'Segoe UI', Helvetica, Arial, sans-serif, 'Apple Color Emoji', 'Segoe UI Emoji', 'Segoe UI Symbol'; padding: 4rem 2rem; direction: ltr">
# <figure style="margin-bottom: 6rem">
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="fr" id="9b1393eb297d4be9ac026ecd4b748637-0" class="displacy" width="23150" height="1274.5" direction="ltr" style="max-width: none; height: 1274.5px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1184.5">
#     <tspan class="displacy-word" fill="currentColor" x="50">MARINE</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1184.5">
#     <tspan class="displacy-word" fill="currentColor" x="225">LE</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1184.5">
#     <tspan class="displacy-word" fill="currentColor" x="400">PEN</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1184.5">
#     <tspan class="displacy-word" fill="currentColor" x="575">SOUHAITE</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="575">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1184.5">
#     <tspan class="displacy-word" fill="currentColor" x="750">UN “</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1184.5">
#     <tspan class="displacy-word" fill="currentColor" x="925">MORATOIRE</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="925">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1184.5">
#     <tspan class="displacy-word" fill="currentColor" x="1100">SUR</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1100">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1184.5">
#     <tspan class="displacy-word" fill="currentColor" x="1275">L’</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1275">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1184.5">
#     <tspan class="displacy-word" fill="currentColor" x="1450">AUGMENTATION</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1450">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1184.5">
#     <tspan class="displacy-word" fill="currentColor" x="1625">DE</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1625">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1184.5">
#     <tspan class="displacy-word" fill="currentColor" x="1800">LA</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1800">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1184.5">
#     <tspan class="displacy-word" fill="currentColor" x="1975">CONTRIBUTION</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1975">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1184.5">
#     <tspan class="displacy-word" fill="currentColor" x="2150">FRANÇAISE</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2150">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1184.5">
#     <tspan class="displacy-word" fill="currentColor" x="2325">À</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2325">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1184.5">
#     <tspan class="displacy-word" fill="currentColor" x="2500">L’</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2500">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1184.5">
#     <tspan class="displacy-word" fill="currentColor" x="2675">UNION</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2675">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1184.5">
#     <tspan class="displacy-word" fill="currentColor" x="2850">EUROPÉENNE”RMC,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2850">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1184.5">
#     <tspan class="displacy-word" fill="currentColor" x="3025">Bourdin</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3025">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1184.5">
#     <tspan class="displacy-word" fill="currentColor" x="3200">Direct,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3200">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1184.5">
#     <tspan class="displacy-word" fill="currentColor" x="3375">le</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3375">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1184.5">
#     <tspan class="displacy-word" fill="currentColor" x="3550">13</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3550">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1184.5">
#     <tspan class="displacy-word" fill="currentColor" x="3725">octobre</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3725">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1184.5">
#     <tspan class="displacy-word" fill="currentColor" x="3900">2020,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3900">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1184.5">
#     <tspan class="displacy-word" fill="currentColor" x="4075">11’20’’IMPOSSIBLE</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4075">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1184.5">
#     <tspan class="displacy-word" fill="currentColor" x="4250">  </tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4250">SPACE</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1184.5">
#     <tspan class="displacy-word" fill="currentColor" x="4425">NewsletterUne</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4425">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1184.5">
#     <tspan class="displacy-word" fill="currentColor" x="4600">fois</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4600">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1184.5">
#     <tspan class="displacy-word" fill="currentColor" x="4775">voté</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4775">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1184.5">
#     <tspan class="displacy-word" fill="currentColor" x="4950">au</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4950">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-a
# Using the 'dep' visualizer
# Serving on http://0.0.0.0:5000 ...

# %% [markdown]
# #### Prédiction des entités Nommées

# %%
# parcourir les entités prédites
for ent in doc.ents:
    # Affiche le texte de l'entité et son label
    print(ent.text, "------->", ent.label_)
# Out:
# MARINE -------> ORG
# PEN -------> ORG
# UNION -------> ORG
# Bourdin Direct -------> PER
# NewsletterUne -------> ORG
# Union -------> LOC
# États membres -------> LOC
# Le Pen -------> PER
# République -------> MISC
# Etats -------> MISC
# Ithry Marouan -------> PER
# Université de Lille -------> ORG
# Vincent Couronne -------> PER
# laboratoire VIP -------> ORG
# Paris -------> LOC
# Saclay -------> LOC

# %%
spacy.explain("MISC"), spacy.explain("GPE"), spacy.explain("NNP"), spacy.explain("dobj")
# Out:
# ('Miscellaneous entities, e.g. events, nationalities, products or works of art',
#  'Countries, cities, states',
#  'noun, proper singular',
#  'direct object')

# %% [markdown]
# #### Visualisatuin des entités Nommées

# %%
from spacy import displacy
displacy.serve(doc, style="ent")
# Out:
# /home/rachida/anaconda3/lib/python3.8/site-packages/spacy/displacy/__init__.py:94: UserWarning: [W011] It looks like you're calling displacy.serve from within a Jupyter notebook or a similar environment. This likely means you're already running a local web server, so there's no need to make displaCy start another one. Instead, you should be able to replace displacy.serve with displacy.render to show the visualization.
#   warnings.warn(Warnings.W011)
# <span class="tex2jax_ignore"><!DOCTYPE html>
# <html lang="fr">
#     <head>
#         <title>displaCy</title>
#     </head>
#
#     <body style="font-size: 16px; font-family: -apple-system, BlinkMacSystemFont, 'Segoe UI', Helvetica, Arial, sans-serif, 'Apple Color Emoji', 'Segoe UI Emoji', 'Segoe UI Symbol'; padding: 4rem 2rem; direction: ltr">
# <figure style="margin-bottom: 6rem">
# <div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     MARINE
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  LE
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     PEN
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  SOUHAITE UN “MORATOIRE SUR L’AUGMENTATION DE LA CONTRIBUTION FRANÇAISE À L’
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     UNION
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  EUROPÉENNE”RMC,
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Bourdin Direct
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
# , le 13 octobre 2020, 11’20’’IMPOSSIBLE
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     NewsletterUne
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  fois voté au sein de l’
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Union
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
# , le budget européen doit être respecté par tous les
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     États membres
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
# . Marine
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Le Pen
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
# , si elle est élue à la présidence de la
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     République
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">MISC</span>
# </mark>
# , ne pourra suspendre le versement français qu’en renégociant ce budget avec les 26 autres
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Etats
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">MISC</span>
# </mark>
# , ce qui n’est pas prévu par les traités. Ou alors elle devra attendre l’échéance de 2027, date prévue pour la négociation du prochain budget.Par
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Ithry Marouan
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
# , étudiante en master droit européen à l'
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Université de Lille
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# , sous la direction de
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Vincent Couronne
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
# , docteur en droit européen, chercheur au
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     laboratoire VIP
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  (
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Paris
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
# -
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Saclay
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
# ), le 15 octobre 2020</div>
# </figure>
# </body>
# </html></span>
# Using the 'ent' visualizer
# Serving on http://0.0.0.0:5000 ...
