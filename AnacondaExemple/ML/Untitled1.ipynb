# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
pd.set_option('display.max_row',13)
pd.set_option('display.max_column',13)#c'est fonction de pandas
data=pd.read_csv("Shill Bidding Dataset.csv",sep=',')#c'est fonction de pandas
data.shape
#data.dtypes.value_counts().plot.pie()#afficher la comanbaire de chaque type.c'est fonction de pandas
#data.head()
#data.columns
# Out:
# (6321, 13)

# %%
da=data.copy()
da=da.drop(columns=['Bidder_ID'],axis=1)
for col in da:
    plt.figure()
    da[col].plot(kind = "kde")

# %%
for col in da:#on parcoure les ariable que on a et on affiche les variable de type float
    #print(col)
    plt.figure()#permit d'afficher chaque variable dans un graphe separer
    sns.distplot(da[col])
# Out:
# /home/rachida/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /home/rachida/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %%
for col in da:
    da[col].plot(kind = "hist", normed = True, color = "lightgrey")
    da[col].plot(kind = "kde")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-11-37b4dd6e9701> in <module>
#       1 for col in da:
# ----> 2     da[col].plot(kind = "hist", normed = True, color = "lightgrey")
#       3     da[col].plot(kind = "kde")
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/plotting/_core.py in __call__(self, *args, **kwargs)
#     947                     data.columns = label_name
#     948
# --> 949         return plot_backend.plot(data, kind=kind, **kwargs)
#     950
#     951     __call__.__doc__ = __doc__
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/plotting/_matplotlib/__init__.py in plot(data, kind, **kwargs)
#      59             kwargs["ax"] = getattr(ax, "left_ax", ax)
#      60     plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 61     plot_obj.generate()
#      62     plot_obj.draw()
#      63     return plot_obj.result
#
# ...

# %%
for col in da:
    da.boxplot(column= da[col])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-31-4d3a6392dc18> in <module>
#       1 for col in da:
# ----> 2     da.boxplot(column= da[col])
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/plotting/_core.py in boxplot_frame(self, column, by, ax, fontsize, rot, grid, figsize, layout, return_type, backend, **kwargs)
#     492 ):
#     493     plot_backend = _get_plot_backend(backend)
# --> 494     return plot_backend.boxplot_frame(
#     495         self,
#     496         column=column,
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/plotting/_matplotlib/boxplot.py in boxplot_frame(self, column, by, ax, fontsize, rot, grid, figsize, layout, return_type, **kwds)
#     378     import matplotlib.pyplot as plt
#     379
# --> 380     ax = boxplot(
#     381         self,
#     382         column=column,
#
# ...

# %%
#data.isna()#elle verifier si une valeur is not a number c'est fonction de pandas
data.describe()#permet de décrire toutes les variables quantitatives d'un jeu de données directement
# Out:
#           Record_ID   Auction_ID  Bidder_Tendency  Bidding_Ratio  \
# count   6321.000000  6321.000000      6321.000000    6321.000000
# mean    7535.829457  1241.388230         0.142541       0.127670
# std     4364.759137   735.770789         0.197084       0.131530
# min        1.000000     5.000000         0.000000       0.011765
# 25%     3778.000000   589.000000         0.027027       0.043478
# 50%     7591.000000  1246.000000         0.062500       0.083333
# 75%    11277.000000  1867.000000         0.166667       0.166667
# max    15144.000000  2538.000000         1.000000       1.000000
#
#        Successive_Outbidding  Last_Bidding  Auction_Bids  \
# count            6321.000000   6321.000000   6321.000000
# mean                0.103781      0.463119      0.231606
# std                 0.279698      0.380097      0.255252
# min                 0.000000      0.000000      0.000000
# 25%                 0.000000      0.047928      0.000000
# ...

# %%
plt.figure(figsize=(20,10))
sns.heatmap(data.isna())#une fonction de seaborn
# Out:
# <AxesSubplot:>

# %%
data.isna().sum()/data.shape[0]#indique le nombre de variable manquante
# Out:
# Record_ID                 0.0
# Auction_ID                0.0
# Bidder_ID                 0.0
# Bidder_Tendency           0.0
# Bidding_Ratio             0.0
# Successive_Outbidding     0.0
# Last_Bidding              0.0
# Auction_Bids              0.0
# Starting_Price_Average    0.0
# Early_Bidding             0.0
# Winning_Ratio             0.0
# Auction_Duration          0.0
# Class                     0.0
# dtype: float64

# %%
data.isna().sum()/data.shape[0]<0.9
# Out:
# Record_ID                 True
# Auction_ID                True
# Bidder_ID                 True
# Bidder_Tendency           True
# Bidding_Ratio             True
# Successive_Outbidding     True
# Last_Bidding              True
# Auction_Bids              True
# Starting_Price_Average    True
# Early_Bidding             True
# Winning_Ratio             True
# Auction_Duration          True
# Class                     True
# dtype: bool

# %%
data[data.columns[data.isna().sum()/data.shape[0]<0.9]]#la pour éliminer les variable qui en un porcentage + de 0.9 de valeurs NAN
# Out:
#       Record_ID  Auction_ID Bidder_ID  Bidder_Tendency  Bidding_Ratio  \
# 0             1         732     _***i         0.200000       0.400000
# 1             2         732     g***r         0.024390       0.200000
# 2             3         732     t***p         0.142857       0.200000
# 3             4         732     7***n         0.100000       0.200000
# 4             5         900     z***z         0.051282       0.222222
# ...         ...         ...       ...              ...            ...
# 6316      15129         760     l***t         0.333333       0.160000
# 6317      15137        2481     s***s         0.030612       0.130435
# 6318      15138        2481     h***t         0.055556       0.043478
# 6319      15139        2481     d***d         0.076923       0.086957
# 6320      15144        2481     a***l         0.016393       0.043478
#
#       Successive_Outbidding  Last_Bidding  Auction_Bids  \
# 0                       0.0      0.000028      0.000000
# ...

# %%
da=data.copy()
da=da.drop(columns=['Record_ID','Auction_ID','Bidder_ID'],axis=1)

# %%
da['Class'].value_counts(normalize=True)#afficher le porcentage de chaque type de cette variable.
# Out:
# 0    0.893213
# 1    0.106787
# Name: Class, dtype: float64

# %%
for col in da:#on parcoure les variables que on a et on affiche les variables de type float
    #print(col)
    plt.figure()#permit d'afficher chaque variable dans un graphe separer
    sns.distplot(da[col])
# Out:
# /home/rachida/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /home/rachida/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %%
da['Class'].unique()#elle pricise les types de donnees de cette variables
# Out:
# array([0, 1])

# %%
for col in da:#on parcoure les variable de type int
    print(f'{col :-<50}{da[col].unique()}')#affiche les catigure de donnee de chaque variable de ce type.
    #plt.figure()#permit d'afficher chaque variable dans un graphe separer
    #sns.distplot(data[col])
# Out:
# Bidder_Tendency-----------------------------------[0.2        0.02439024 0.14285714 0.1        0.05128205 0.03846154
#  0.4        0.13793103 0.12195122 0.15517241 0.6        0.5
#  0.01724138 0.04132231 0.00724638 0.01       0.02564103 0.17241379
#  0.01030928 0.25       0.02325581 0.04166667 0.11111111 0.05263158
#  1.         0.0173913  0.04545454 0.07017544 0.06666667 0.22222222
#  0.04347826 0.15789474 0.57142857 0.00980392 0.21052632 0.48148148
#  0.10344828 0.05882353 0.02272727 0.02597403 0.07142857 0.02083333
#  0.01176471 0.03448276 0.08333333 0.01449275 0.18181818 0.10526316
#  0.125      0.01020408 0.04       0.01041667 0.01298701 0.02702703
#  0.         0.07826087 0.75       0.025      0.06060606 0.05405405
#  0.02666667 0.01515152 0.02857143 0.33333333 0.16666667 0.00869565
#  0.01208459 0.05660377 0.03333333 0.08       0.01408451 0.09090909
#  0.26666667 0.18       0.05       0.46666667 0.45454545 0.03030303
# ...

# %%
#da=da.drop(columns=['Record_ID','Auction_ID','Bidder_Tendency','Auction_Duration','Bidder_ID'],axis=1)
#for col in da:
    #plt.figure()
    #da[col].value_counts().plot.pie()
    #sns.distplot(data[col])
data_Nigatif=data[data['Class']==1]
data_Nigatif['Auction_Duration'].value_counts().plot.pie( autopct='%1.1f%%', shadow=True, startangle=90, radius=0.4, 
     center=(0.5,0.5), 
     frame=True, pctdistance=1.125).legend()

# %%
data_Nigatif=data[data['Class']==0]
data_Nigatif['Auction_Duration'].value_counts().plot.pie( 
     autopct='%1.1f%%', shadow=True, startangle=90, radius=0.4, 
     center=(0.5,0.5), 
     frame=True, pctdistance=1.125).legend()

# %%
data_Positif=da[da['Class']==0]
data_Positif
# Out:
#       Record_ID  Auction_ID  Bidder_Tendency  Bidding_Ratio  \
# 0             1         732         0.200000       0.400000
# 1             2         732         0.024390       0.200000
# 2             3         732         0.142857       0.200000
# 3             4         732         0.100000       0.200000
# 4             5         900         0.051282       0.222222
# ...         ...         ...              ...            ...
# 6315      15128         760         0.022222       0.040000
# 6317      15137        2481         0.030612       0.130435
# 6318      15138        2481         0.055556       0.043478
# 6319      15139        2481         0.076923       0.086957
# 6320      15144        2481         0.016393       0.043478
#
#       Successive_Outbidding  Last_Bidding  Auction_Bids  \
# 0                       0.0      0.000028      0.000000
# 1                       0.0      0.013123      0.000000
# 2                       0.0      0.003042      0.000000
# ...

# %%
data_Nigatif=da[da['Class']==1]
data_Nigatif
# Out:
#       Record_ID  Auction_ID  Bidder_Tendency  Bidding_Ratio  \
# 7            12         900         0.137931       0.444444
# 8            13        2370         0.121951       0.185185
# 9            27         600         0.155172       0.346154
# 10           37        2172         0.600000       0.562500
# 13           40        2236         0.041322       0.208333
# ...         ...         ...              ...            ...
# 6284      15047        1395         0.239130       0.343750
# 6285      15052        2378         0.281690       0.740741
# 6289      15060        1277         0.592593       0.615385
# 6295      15070         342         0.200000       0.111111
# 6316      15129         760         0.333333       0.160000
#
#       Successive_Outbidding  Last_Bidding  Auction_Bids  \
# 7                       1.0      0.768044      0.000000
# 8                       1.0      0.035021      0.333333
# 9                       0.5      0.570994      0.307692
# ...

# %%
for col in da:
    plt.figure()
    sns.distplot(data_Positif[col],label='positif')
    sns.distplot(data_Nigatif[col],label='negatif')
    plt.legend()
# Out:
# /home/rachida/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /home/rachida/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %%
d=data.copy()
sns.countplot(x='Successive_Outbidding',hue='Class',data=d)#la on count le nombre d'aperstion de Auction_Duration pour les class 0 et 1

# %%
    sns.heatmap(pd.crosstab(data['Class'],data['Auction_Duration']),annot=True,fmt='d')

# %%
sns.pairplot(data)

# %%
# devision de dataset par rapport a la classe 
da=data.copy()
da=da.drop(columns=['Record_ID','Auction_ID','Auction_Duration','Bidder_ID'],axis=1)
data_Nigatif=da[da['Class']==1]
data_Positif=da[da['Class']==0]
data_Nigatif=data_Nigatif.drop(columns=['Class'])
data_Nigatif.corr()
# Out:
#                         Bidder_Tendency  Bidding_Ratio  Successive_Outbidding  \
# Bidder_Tendency                1.000000       0.037624               0.087859
# Bidding_Ratio                  0.037624       1.000000               0.293254
# Successive_Outbidding          0.087859       0.293254               1.000000
# Last_Bidding                   0.154630      -0.134328               0.050285
# Auction_Bids                   0.203161      -0.453256               0.012526
# Starting_Price_Average         0.172738      -0.358157              -0.023056
# Early_Bidding                  0.186503      -0.181016               0.046635
# Winning_Ratio                  0.042172      -0.131250               0.039398
#
#                         Last_Bidding  Auction_Bids  Starting_Price_Average  \
# Bidder_Tendency             0.154630      0.203161                0.172738
# Bidding_Ratio              -0.134328     -0.453256               -0.358157
# ...

# %%
data_Positif.corr()
# Out:
#                         Bidder_Tendency  Bidding_Ratio  Successive_Outbidding  \
# Bidder_Tendency                1.000000       0.205347               0.129508
# Bidding_Ratio                  0.205347       1.000000               0.237120
# Successive_Outbidding          0.129508       0.237120               1.000000
# Last_Bidding                  -0.005479      -0.161719               0.021168
# Auction_Bids                   0.056038      -0.480376               0.075542
# Starting_Price_Average         0.045076      -0.349345               0.050961
# Early_Bidding                 -0.026998      -0.237892               0.013909
# Winning_Ratio                  0.120675       0.695769               0.084856
# Class                               NaN            NaN                    NaN
#
#                         Last_Bidding  Auction_Bids  Starting_Price_Average  \
# Bidder_Tendency            -0.005479      0.056038                0.045076
# ...

# %%
#sns.heatmap(data.corr())
#da=data("")
da.corr()
# Out:
#                         Bidding_Ratio  Successive_Outbidding  Last_Bidding  \
# Bidding_Ratio                1.000000               0.604828     -0.066541
# Successive_Outbidding        0.604828               1.000000      0.098941
# Last_Bidding                -0.066541               0.098941      1.000000
# Auction_Bids                -0.347831               0.065361      0.297639
# Starting_Price_Average      -0.252289               0.052263      0.293323
# Early_Bidding               -0.147773               0.056798      0.950096
# Winning_Ratio                0.642905               0.382002     -0.076726
# Class                        0.569435               0.901035      0.097655
#
#                         Auction_Bids  Starting_Price_Average  Early_Bidding  \
# Bidding_Ratio              -0.347831               -0.252289      -0.147773
# Successive_Outbidding       0.065361                0.052263       0.056798
# ...

# %%
sns.clustermap(data.corr())

# %%
#d=data[data.columns[data.dtypes == 'float']]

for col in da :
    plt.figure()
    sns.lmplot(x='Winning_Ratio',y=col,hue='Class',data=da)

# %%
da.corr()['Winning_Ratio']

# %%
da.corr()['Winning_Ratio'].sort_values()

# %%
da.describe()

# %%
da.tail()

# %%
da.nunique()

# %%
da.isna().sum()
# Out:
# Bidder_Tendency           0
# Bidding_Ratio             0
# Successive_Outbidding     0
# Last_Bidding              0
# Auction_Bids              0
# Starting_Price_Average    0
# Early_Bidding             0
# Winning_Ratio             0
# Auction_Duration          0
# Class                     0
# dtype: int64

# %%
da.shape
# Out:
# (6321, 10)

# %%
da["Bidding_Ratio"].sum()
# Out:
# 807.00000018

# %%
da1= da[da["Bidding_Ratio"]>=0.0]

da["Bidding_Ratio"].sum()
# Out:
# 807.00000018

# %%
da1["Bidding_Ratio"].mean()
# Out:
# 0.12766967254864764

# %%
da1["Bidding_Ratio"].median()
# Out:
# 0.083333333

# %%
#da["Bidding_Ratio"].unique()

# %%
da["Successive_Outbidding"].mean()
# Out:
# 0.10378104730264198

# %%
da["Successive_Outbidding"].sum()
# Out:
# 656.0

# %%
da["Successive_Outbidding"].unique()
# Out:
# array([0. , 1. , 0.5])

# %%
da.groupby("Class").mean()
# Out:
#        Bidder_Tendency  Bidding_Ratio  Successive_Outbidding  Last_Bidding  \
# Class
# 0             0.122403       0.101775               0.016649      0.450286
# 1             0.310979       0.344268               0.832593      0.570463
#
#        Auction_Bids  Starting_Price_Average  Early_Bidding  Winning_Ratio
# Class
# 0          0.227638                0.465605       0.423630       0.308242
# 1          0.264797                0.533181       0.489674       0.865322

# %%
da.dtypes
# Out:
# Bidder_Tendency           float64
# Bidding_Ratio             float64
# Successive_Outbidding     float64
# Last_Bidding              float64
# Auction_Bids              float64
# Starting_Price_Average    float64
# Early_Bidding             float64
# Winning_Ratio             float64
# Auction_Duration            int64
# Class                       int64
# dtype: object

# %%
#da['Bidding_Ratio'].unique()
da["Bidding_Ratio"].sum()
da1= da[da["Bidding_Ratio"]<=0.1]

da1["Bidding_Ratio"].sum()
# Out:
# 198.458038526

# %%
#on remarque que la variable Bidding_Ratio a une forte relation avec la fraude car 
#si le soumissionaire participe a des plus grande enchere il ya plus de fraude 
da.groupby("Class").mean()
# Out:
#        Bidding_Ratio  Successive_Outbidding  Last_Bidding  Auction_Bids  \
# Class
# 0           0.101775               0.016649      0.450286      0.227638
# 1           0.344268               0.832593      0.570463      0.264797
#
#        Starting_Price_Average  Early_Bidding  Winning_Ratio
# Class
# 0                    0.465605       0.423630       0.308242
# 1                    0.533181       0.489674       0.865322

# %%
#da['Successive_Outbidding'].unique()
#da["Successive_Outbidding"].sum()
da1= da[da["Successive_Outbidding"]<0.5]

da1["Successive_Outbidding"].sum()
# Out:
# 0.0

# %%
#la aussi on remarque que si le enchérissseur ce surchere successivement avec des des
#incriments > 0.5 la on remarque que les deux classe vont etre equiliberé avce des 
da1.groupby("Class").mean()
# Out:
#        Bidder_Tendency  Bidding_Ratio  Successive_Outbidding  Last_Bidding  \
# Class
# 0             0.313677       0.217836                    1.0      0.766575
# 1             0.330502       0.384018                    1.0      0.583790
#
#        Auction_Bids  Starting_Price_Average  Early_Bidding  Winning_Ratio  \
# Class
# 0          0.548595                0.883528       0.756554       0.286435
# 1          0.266077                0.524968       0.502975       0.869975
#
#        Auction_Duration
# Class
# 0              7.222222
# 1              4.552106

# %%
da.groupby("Class").mean()
# Out:
#        Bidder_Tendency  Bidding_Ratio  Successive_Outbidding  Last_Bidding  \
# Class
# 0             0.122403       0.101775               0.016649      0.450286
# 1             0.310979       0.344268               0.832593      0.570463
#
#        Auction_Bids  Starting_Price_Average  Early_Bidding  Winning_Ratio  \
# Class
# 0          0.227638                0.465605       0.423630       0.308242
# 1          0.264797                0.533181       0.489674       0.865322
#
#        Auction_Duration
# Class
# 0              4.597060
# 1              4.765926

# %%
da['Winning_Ratio'].sort_values()==0.5
# Out:
#   File "<ipython-input-151-cce7c492e51d>", line 1
#     da['Winning_Ratio'].sort_values()==0.5:
#                                            ^
# SyntaxError: invalid syntax

# %%
#da["Winning_Ratio"].sort_values()
da1= da[da["Winning_Ratio"]>0.5]

da1["Winning_Ratio"].sum()
# Out:
# 2288.228905924

# %%
da.groupby("Class").mean()
# Out:
#        Bidder_Tendency  Bidding_Ratio  Successive_Outbidding  Last_Bidding  \
# Class
# 0             0.122403       0.101775               0.016649      0.450286
# 1             0.310979       0.344268               0.832593      0.570463
#
#        Auction_Bids  Starting_Price_Average  Early_Bidding  Winning_Ratio  \
# Class
# 0          0.227638                0.465605       0.423630       0.308242
# 1          0.264797                0.533181       0.489674       0.865322
#
#        Auction_Duration
# Class
# 0              4.597060
# 1              4.765926

# %%
da1.groupby("Class").mean()
# Out:
#        Bidder_Tendency  Bidding_Ratio  Successive_Outbidding  Last_Bidding  \
# Class
# 0             0.143960       0.191086               0.027892      0.376550
# 1             0.298529       0.341568               0.834615      0.574663
#
#        Auction_Bids  Starting_Price_Average  Early_Bidding  Winning_Ratio  \
# Class
# 0          0.064999                0.244294       0.322229       0.877330
# 1          0.265856                0.533797       0.494101       0.882963
#
#        Auction_Duration
# Class
# 0              4.457011
# 1              4.781538

# %%
data.unique()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-7-29a79790751a> in <module>
# ----> 1 data.unique()
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5137             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5138                 return self[name]
# -> 5139             return object.__getattribute__(self, name)
#    5140
#    5141     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'unique'

# %%
da=data.drop(columns=['Record_ID','Auction_ID','Bidder_Tendency','Auction_Duration','Bidder_ID'],axis=1)
data_Nigatif=da[da['Class']==1]
data_Positif=da[da['Class']==0]
data_Positif=data_Positif.drop(columns=['Class'])
data_Positif.describe()
# Out:
#        Bidding_Ratio  Successive_Outbidding  Last_Bidding  Auction_Bids  \
# count    5646.000000            5646.000000   5646.000000   5646.000000
# mean        0.101775               0.016649      0.450286      0.227638
# std         0.093187               0.098199      0.380862      0.255699
# min         0.011765               0.000000      0.000000      0.000000
# 25%         0.040000               0.000000      0.037324      0.000000
# 50%         0.071429               0.000000      0.410174      0.100000
# 75%         0.125000               0.000000      0.851196      0.454545
# max         0.857143               1.000000      0.999900      0.788235
#
#        Starting_Price_Average  Early_Bidding  Winning_Ratio
# count             5646.000000    5646.000000    5646.000000
# mean                 0.465605       0.423630       0.308242
# std                  0.489642       0.381178       0.421624
# min                  0.000000       0.000000       0.000000
# ...
